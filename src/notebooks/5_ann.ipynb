# %%
import pandas as pd

df = pd.read_csv('../../output_data/4_2_vectorized_ds.csv')

df.info(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\reosk\projects\text-categorizer\src\notebooks\5_ann.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> df = pd.read_csv('../../output_data/4_2_vectorized_ds.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> df.info(5)
#
# ...

# %%
import pandas as pd

df = pd.read_csv('../../output_data/4_2_vectorized_ds.csv')

df.info(5)
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# c:\Users\reosk\projects\text-categorizer\src\notebooks\5_ann.ipynb Cell 1 line 3
#
#       <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ----> <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> df = pd.read_csv('../../output_data/4_2_vectorized_ds.csv')
#
#       <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> df.info(5)
#
#
#
# ...

# %%
import pandas as pd

df = pd.read_csv('../../output_data/4_2_vectorized_ds.csv')

df.info(5)
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# c:\Users\reosk\projects\text-categorizer\src\notebooks\5_ann.ipynb Cell 1 line 3
#
#       <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ----> <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> df = pd.read_csv('../../output_data/4_2_vectorized_ds.csv')
#
#       <a href='vscode-notebook-cell:/c%3A/Users/reosk/projects/text-categorizer/src/notebooks/5_ann.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> df.info(5)
#
#
#
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0   input_0   input_1   input_2   input_3   input_4   input_5  \
# 0           0  0.187500  0.015747 -0.058594  0.083496 -0.063477  0.122559
# 1           1  0.113770  0.110840  0.043213 -0.194336  0.140625 -0.460938
# 2           2 -0.051025  0.045898 -0.273438 -0.259766  0.347656  0.026611
# 3           3  0.208008 -0.076660 -0.000389  0.123535  0.316406 -0.281250
# 4           4  0.011292  0.028931  0.083496 -0.049805 -0.130859 -0.109863
#
#     input_6   input_7   input_8  ...  input_13194  input_13195  input_13196  \
# 0  0.127930  0.002411  0.263672  ...          NaN          NaN          NaN
# 1  0.022217 -0.084961 -0.047852  ...          NaN          NaN          NaN
# 2 -0.217773 -0.182617 -0.247070  ...          NaN          NaN          NaN
# 3  0.251953 -0.326172  0.026123  ...          NaN          NaN          NaN
# 4 -0.115234 -0.074707 -0.089355  ...          NaN          NaN          NaN
#
#    input_13197  input_13198  input_13199          tag  \
# ...

# %%
# Transform TAG to numerical value

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()


df['TAG_transformed'] = le.fit_transform(df['tag'])

# %%
df.head(3)
# Out:
#    Unnamed: 0   input_0   input_1   input_2   input_3   input_4   input_5  \
# 0           0  0.187500  0.015747 -0.058594  0.083496 -0.063477  0.122559
# 1           1  0.113770  0.110840  0.043213 -0.194336  0.140625 -0.460938
# 2           2 -0.051025  0.045898 -0.273438 -0.259766  0.347656  0.026611
#
#     input_6   input_7   input_8  ...  input_13195  input_13196  input_13197  \
# 0  0.127930  0.002411  0.263672  ...          NaN          NaN          NaN
# 1  0.022217 -0.084961 -0.047852  ...          NaN          NaN          NaN
# 2 -0.217773 -0.182617 -0.247070  ...          NaN          NaN          NaN
#
#    input_13198  input_13199          tag  \
# 0          NaN          NaN    COMMUNITY
# 1          NaN          NaN  ENVIRONMENT
# 2          NaN          NaN        RELAX
#
#                                           lemmatized  \
# 0  ['personal', 'ranking', 'community', 'use', 'a...
# 1  ['took', '30', 'year', 'climate', 'tech', 'inv...
# ...
